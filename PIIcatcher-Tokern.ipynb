# %%
from dbcat.api import open_catalog, add_sqlite_source
from piicatcher.api import scan_database

catalog = open_catalog(app_dir='/tmp/.config/piicatcher', path=':memory:', secret='my_secret')

# %%
with catalog.managed_session:
    # Add a postgresql source
    source = add_sqlite_source(catalog=catalog, name="sqldb6", path="/home/hitesh/fedml/pii/sakila_master.db")
    output = scan_database(catalog=catalog, source=source)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 4
#       1 with catalog.managed_session:
#       2     # Add a postgresql source
#       3     source = add_sqlite_source(catalog=catalog, name="sqldb6", path="/home/hitesh/fedml/pii/sakila_master.db")
# ----> 4     output = scan_database(catalog=catalog, source=source)
#
# File ~/fedml/pii/venv/lib/python3.9/site-packages/piicatcher/api.py:43, in scan_database(catalog, source, scan_type, incremental, output_format, list_all, include_schema_regex, exclude_schema_regex, include_table_regex, exclude_table_regex, sample_size)
#      28 def scan_database(
#      29     catalog: Catalog,
#      30     source: CatSource,
#    (...)
#      39     sample_size: int = SMALL_TABLE_MAX,
#      40 ) -> Union[List[Any], Dict[Any, Any]]:
# ...

# %%
with catalog.managed_session:
    source = add_sqlite_source(catalog=catalog, name="sqldb4", path="/home/hitesh/fedml/pii/sakila_master.db")
    print(source)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~/fedml/pii/venv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1276, in Connection._execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275     if not evt_handled:
# -> 1276         self.dialect.do_execute(
#    1277             cursor, statement, parameters, context
#    1278         )
#    1280 if self._has_events or self.engine._has_events:
#
# File ~/fedml/pii/venv/lib/python3.9/site-packages/sqlalchemy/engine/default.py:608, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     607 def do_execute(self, cursor, statement, parameters, context=None):
# --> 608     cursor.execute(statement, parameters)
#
# IntegrityError: UNIQUE constraint failed: sources.name
#
# The above exception was the direct cause of the following exception:
#
# ...
